# %% [markdown]
# # HAND CRICKET

# %%
import random

def play_hand_cricket():
    print("Welcome to Hand Cricket!\n")

    def get_choice(prompt):
        while True:
            try:
                choice = int(input(prompt))
                if 1 <= choice <= 6:
                    return choice
                print("Invalid choice. Choose a number between 1 and 6.")
            except ValueError:
                print("Invalid input. Enter a number between 1 and 6.")

    player_score = 0
    print("Your turn to bat!")
    while True:
        player_choice = get_choice("Choose a number (1-6): ")
        computer_choice = random.randint(1, 6)
        print(f"Computer bowled: {computer_choice}")
        if player_choice == computer_choice:
            print("You're out!")
            break
        player_score += player_choice
        print(f"Your score: {player_score}")

    print(f"You scored: {player_score}\n")

    computer_score = 0
    print("Now it's the computer's turn to bat!")
    while True:
        player_choice = get_choice("Choose a number to bowl (1-6): ")
        computer_choice = random.randint(1, 6)
        print(f"Computer chose: {computer_choice}")
        if player_choice == computer_choice:
            print("Computer is out!")
            break
        computer_score += computer_choice
        print(f"Computer's score: {computer_score}")
        if computer_score > player_score:
            print("Computer wins!")
            return

    print(f"Computer scored: {computer_score}\n")

    if player_score > computer_score:
        print("You win!")
    elif player_score < computer_score:
        print("Computer wins!")
    else:
        print("It's a tie!")

if __name__ == "__main__":
    play_hand_cricket()
# Out:
# Welcome to Hand Cricket!
#
# Your turn to bat!
# Choose a number (1-6): 2
# Computer bowled: 1
# Your score: 2
# Choose a number (1-6): 1
# Computer bowled: 6
# Your score: 3
# Choose a number (1-6): 2
# Computer bowled: 1
# Your score: 5
# Choose a number (1-6): 3
# Computer bowled: 1
# Your score: 8
# Choose a number (1-6): 4
# Computer bowled: 6
# Your score: 12
# Choose a number (1-6): 5
# Computer bowled: 3
# Your score: 17
# Choose a number (1-6): 6
# Computer bowled: 5
# Your score: 23
# Choose a number (1-6): 2
# Computer bowled: 3
# Your score: 25
# Choose a number (1-6): 4
# Computer bowled: 5
# Your score: 29
# Choose a number (1-6): 6
# Computer bowled: 3
# Your score: 35
# Choose a number (1-6): 2
# Computer bowled: 5
# Your score: 37
# Choose a number (1-6): 1
# Computer bowled: 2
# Your score: 38
# Choose a number (1-6): 2
# Computer bowled: 2
# You're out!
# You scored: 38
#
# Now it's the computer's turn to bat!
# Choose a number to bowl (1-6): 1
# Computer chose: 4
# ...
